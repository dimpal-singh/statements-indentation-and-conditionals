# %%
text = "10000"
int_text = int("1000")
int_text = int("1000")

# %%
my_set = [1,1,2,2,3,4,6,6,6,8,9,7,5,5]
my_list = my_list(set)
print(my_list)

# %%
if (text== "rain"):
  print("weather is not good")
  print("i will not go to office")
elif (text== "sunny"):
  print("weather is too hot")
  print("i will not go to office")
else :
  print("weather is good")
  print("i will go to office")
# Out:
# weather is good
# i will go to office

# %%
temperature = 100
if temperature < 90:
  print("lets go to park")
else:
  print("lets stay inside and play vidio game")
# Out:
# lets stay inside and play vidio game

# %%
a = 10
b = 11

if (a != b):
 print("i am testing")
 print("demo for if condition")
 print("a and b are eqaul")

print("this line is out of the scope of if condition")
# Out:
# i am testing
# demo for if condition
# a and b are eqaul
# this line is out of the scope of if condition

# %%
age = int(input())
if age >=18:
  print("you are an adult")
# Out:
# 20
# you are an adult

# %%
marks = 65
if marks >30:
  print("you have the exam")
else:
  print("you have failed")
# Out:
# you have the exam

# %%
number = input("Enter a valid number")
number = int(number)
if (number%2 == 0):
  print("The number is even")
  print(number ** 2)
elif (number%2 !=0):
  print("Number is odd")
  print(number ** 3)
else:
  print("Enter a valid number")
# Out:
# Enter a valid number7
# Number is odd
# 343

# %%
speed = 60
if speed >50:
  print("go slow down")
# Out:
# go slow down

# %%
age = int(input())
if age >=18:
  print("you are an adult")
else:
  print("you are not an adult")
# Out:
# 20
# you are an adult

# %%
score = 45
if score >= 60:
  print("congratulation")
else:
  print("sorry,you failled")
# Out:
# sorry,you failled

# %%
age = int(input())
if age >=18:
  print("you are an adult")
elif age >= 13:
    print("you are a teenager")
else:
    print("you are a child")
# Out:
# 20
# you are an adult

# %%
age = 20
status = "adult" if age>=18 else "minor"
print(status)
# Out:
# adult

# %%
status = None
age = 20
if age>18:
  status = "adult"
else:
  status = "minor"
  print(status)

# %%
a = 1
b = 0
c= 1

if a>0:
  print("i am inside first if condition")
  if(b>0):
    print("i am inside first nested if conditio")
    if(c>0):
      print("i am inside secend nested if condition")
# Out:
# i am inside first if condition

# %%
age = int(input("Enter your age:"))
height = int(input("Enter your height in cm:"))
if age >=10:
  print("you are old enough to ride the rollercoaster")
  if height >=120:
    print("and you meet the height requirement.")
  else:
    print("but you you do not meet the height requirement.")
else:
    print("you are not eligible to ride the rollercoaster because you are too young")
# Out:
# Enter your age:20
# Enter your height in cm:100
# you are old enough to ride the rollercoaster
# but you you do not meet the height requirement.

# %%
number1 = 1
number2 = 9
number = 10
if (number1 > 0) or (number2 <10 ) and (number3 < 11):
  print(number2 + number1)
elif number1 < 0:
  print("Ah, that's a negative number")
else:
  print("The number is zero")
# Out:
# 10

# %%
my_list = ['cow','cow','pigeon','jackal','Dog','dog','Dolphin',]
print(max(my_list))
# Out:
# pigeon
